# %% [markdown]
# <a href="https://colab.research.google.com/github/shahanayc/copy-of-dashboard/blob/main/AML-2%20HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
def sig(x):
 return 1/(1 + np.exp(-x))

def tanh(x):
  return (np.exp(x)-np.exp(-x))/(np.exp(x)np.exp(-x))

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
x = np.linspace(-10, 10, 50)
p = sig(x)
plt.xlabel("x")
plt.ylabel("y")
#plt.plot(x, p, color="green")

q= tanh(x)
#plt.ylabel("hyperbolic tangent(x)")
#plt.plot(x,q, color="orange");
plt.title("Sigmoid vs hyperbolic tangent functions")

X = np.arange(0, math.pi*2, 0.05)
plt.plot(X, p, color='r', label='sin')
plt.plot(X, q, color='g', label='cos')

plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-69720686fde0> in <cell line: 16>()
#      14
#      15 X = np.arange(0, math.pi*2, 0.05)
# ---> 16 plt.plot(X, p, color='r', label='sin')
#      17 plt.plot(X, q, color='g', label='cos')
#      18
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1686         """
#    1687         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...

# %%
# Importing libraries
import matplotlib.pyplot as plt
import numpy as np
import math

def sig(x):
 return 1/(1 + np.exp(-x))

def tanh(x):
  return (np.exp(x)-np.exp(-x))/(np.exp(x)+np.exp(-x))

# Using Numpy to create an array X
X = np.linspace(-10,10,50)

# Assign variables to the y axis part of the curve
y = sig(X)
z = tanh(X)

# Plotting both the curves simultaneously
plt.plot(X, y, color='green', label='sig')
plt.plot(X, z, color='orange', label='tanh')

# Naming the x-axis, y-axis and the whole graph
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Sigmoid vs hyperbolic tangent functions")

# Adding legend, which helps us recognize the curve according to it's color
plt.legend()

# To load the display window
plt.show()
